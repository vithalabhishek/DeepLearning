# %%
print("We are learning Numpy")   # shift + enter
# Out:
# We are learning Numpy

# %%
# !pip3 install numpy

# %%
import numpy as np

# %%
a1 = np.array([5,4,3,45,3,4,32,43,4354,5])
print(a1)
# Out:
# [   5    4    3   45    3    4   32   43 4354    5]

# %%
type(a1)
# Out:
# numpy.ndarray

# %%
a2 = np.array([[5,4,3,45,3],[5,3,2,1,4],[5,4,2,42,3]])
print(a2)
# Out:
# [[ 5  4  3 45  3]
#  [ 5  3  2  1  4]
#  [ 5  4  2 42  3]]

# %%
a3 = np.array([[5,4,3,45,3],[5,3,2,1,4,6],[5,4,2,42,3]])
print(a3)
# Out:
# [list([5, 4, 3, 45, 3]) list([5, 3, 2, 1, 4, 6]) list([5, 4, 2, 42, 3])]

# %%
len(a2)
# Out:
# 3

# %%
a2.shape
# Out:
# (3, 5)

# %%
a2 = a2.reshape(5,3)

# %%
a2
# Out:
# array([[ 5,  4,  3],
#        [45,  3,  5],
#        [ 3,  2,  1],
#        [ 4,  5,  4],
#        [ 2, 42,  3]])

# %%
#### Pick the elements from array (Array Slicing)

# %%
a2
# Out:
# array([[ 5,  4,  3],
#        [45,  3,  5],
#        [ 3,  2,  1],
#        [ 4,  5,  4],
#        [ 2, 42,  3]])

# %%
a2[2]
# Out:
# array([3, 2, 1])

# %%
a2[2:5]
# Out:
# array([[ 3,  2,  1],
#        [ 4,  5,  4],
#        [ 2, 42,  3]])

# %%
a2[2:]
# Out:
# array([[ 3,  2,  1],
#        [ 4,  5,  4],
#        [ 2, 42,  3]])

# %%
a2[:6]
# Out:
# array([[ 5,  4,  3],
#        [45,  3,  5],
#        [ 3,  2,  1],
#        [ 4,  5,  4],
#        [ 2, 42,  3]])

# %%
a2[-3]
# Out:
# array([3, 2, 1])

# %%
a2
# Out:
# array([[ 5,  4,  3],
#        [45,  3,  5],
#        [ 3,  2,  1],
#        [ 4,  5,  4],
#        [ 2, 42,  3]])

# %%
a2[3,1]
# Out:
# 5

# %%
a2[1:4,1]
# Out:
# array([3, 2, 5])

# %%
a2
# Out:
# array([[ 5,  4,  3],
#        [45,  3,  5],
#        [ 3,  2,  1],
#        [ 4,  5,  4],
#        [ 2, 42,  3]])

# %%
a2.sum()
# Out:
# 131

# %%
a2.sum(axis=0)    ## column wise sum
# Out:
# array([59, 56, 16])

# %%
a2.sum(axis=1)    ## row wise sum
# Out:
# array([12, 53,  6, 13, 47])

# %%
a2.mean()
# Out:
# 8.733333333333333

# %%
a2[2].sum()
# Out:
# 6

# %%
a2[:,2].sum()
# Out:
# 16

# %%
a2
# Out:
# array([[ 5,  4,  3],
#        [45,  3,  5],
#        [ 3,  2,  1],
#        [ 4,  5,  4],
#        [ 2, 42,  3]])

# %%
a2[2]
# Out:
# array([3, 2, 1])

# %%
a2.sum(axis=0)[2]
# Out:
# 16

# %%
a2
# Out:
# array([[ 5,  4,  3],
#        [45,  3,  5],
#        [ 3,  2,  1],
#        [ 4,  5,  4],
#        [ 2, 42,  3]])

# %%
a2.max()
# Out:
# 45

# %%
a2.min()
# Out:
# 1

# %%
a2.argmax()
# Out:
# 3

# %%
a2.argmin()
# Out:
# 8

# %%
### Generate some equidistant numbers b/w a range
np.linspace(1,100,20)
# Out:
# array([  1.        ,   6.21052632,  11.42105263,  16.63157895,
#         21.84210526,  27.05263158,  32.26315789,  37.47368421,
#         42.68421053,  47.89473684,  53.10526316,  58.31578947,
#         63.52631579,  68.73684211,  73.94736842,  79.15789474,
#         84.36842105,  89.57894737,  94.78947368, 100.        ])

# %%
np.linspace(1,100,20,retstep=True)
# Out:
# (array([  1.        ,   6.21052632,  11.42105263,  16.63157895,
#          21.84210526,  27.05263158,  32.26315789,  37.47368421,
#          42.68421053,  47.89473684,  53.10526316,  58.31578947,
#          63.52631579,  68.73684211,  73.94736842,  79.15789474,
#          84.36842105,  89.57894737,  94.78947368, 100.        ]),
#  5.2105263157894735)

# %%
np.linspace(1,100,10,retstep=True)
# Out:
# (array([  1.,  12.,  23.,  34.,  45.,  56.,  67.,  78.,  89., 100.]), 11.0)

# %%
np.arange(1,102,4.5)
# Out:
# array([  1. ,   5.5,  10. ,  14.5,  19. ,  23.5,  28. ,  32.5,  37. ,
#         41.5,  46. ,  50.5,  55. ,  59.5,  64. ,  68.5,  73. ,  77.5,
#         82. ,  86.5,  91. ,  95.5, 100. ])

# %%
np.linspace(1,1000,20,retstep=True)   ## retstep - display the setp value
# Out:
# (array([   1.        ,   53.57894737,  106.15789474,  158.73684211,
#          211.31578947,  263.89473684,  316.47368421,  369.05263158,
#          421.63157895,  474.21052632,  526.78947368,  579.36842105,
#          631.94736842,  684.52631579,  737.10526316,  789.68421053,
#          842.26315789,  894.84210526,  947.42105263, 1000.        ]),
#  52.578947368421055)

# %%
#### Random Numbers
np.random.randint(50)   ### 0-49
# Out:
# 30

# %%
np.random.seed(3)
np.random.randint(50)   ### 0-49
# Out:
# 42

# %%
np.random.randint(50,500)
# Out:
# 181

# %%
np.random.randint(50,500,10)
# Out:
# array([490, 306, 327, 197, 252, 413, 219, 188, 455, 169])

# %%
np.random.randint(50,500,(3,2))
# Out:
# array([[472, 198],
#        [478, 143],
#        [473, 448]])
